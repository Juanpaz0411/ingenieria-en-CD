# %% [markdown]
# ### Entorno

# %%
import sys, platform, hashlib
from pathlib import Path
import duckdb
import os

PROJECT_ROOT = Path(".").resolve()
DATA_DIR = PROJECT_ROOT / "data"

DB_PATH = DATA_DIR / "exoplanets.duckdb"
con = duckdb.connect(str(DB_PATH))

print("OS:", platform.platform())
print("Python:", sys.version.split()[0])
print("DuckDB:", con.execute("SELECT version()").fetchone()[0])
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[3], line 10
#       7 DATA_DIR = PROJECT_ROOT / "data"
#       9 DB_PATH = DATA_DIR / "exoplanets.duckdb"
# ---> 10 con = duckdb.connect(str(DB_PATH))
#      12 print("OS:", platform.platform())
#      13 print("Python:", sys.version.split()[0])
#
# IOException: IO Error: Cannot open file "c:\users\usuario windows\repositorios\ing\notebooks\data\exoplanets.duckdb": El sistema no puede encontrar la ruta especificada.
